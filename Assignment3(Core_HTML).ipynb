# %% [markdown]
# # **Core HTML**

# %% [markdown]
# **Q1.Build a simple webpage that displays text as shown in the below image.**
# ![Screenshot 2025-09-18 145344.png](data:image/png;base64,...)

# %% [markdown]
# **Ans.**
#
#
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title> Assignment</title>
# </head>
# <body>
#     <b>This text will be bolded.</b>
#     <br><br>
#     <i>This text will be italic.</i>
#     <br><br>
#     <u>This text will be underlined.</u>
#     <br><br>
#     <mark>This text will be highlighted.</mark>
#     <br><br>
#     This is normal text <sup> This will be super scripted </sup> This is normal again
#     <br><br>
#     This is normal text <sub>This text will be subscripted</sub>
#     <br><br>
#     <big>Normal text</big> <small> small Text</small>
#     <br><br>
#     <strike>This text will be deleted</strike>
# </body>
# </html>

# %% [markdown]
#  **Q.2 Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image.**
#
# ![Screenshot 2025-09-18 153245.png](data:image/png;base64,...)

# %% [markdown]
# **Ans.**
#
#
# ```
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title> Assignment</title>
# </head>
# <body>
#     Take me to <a href="https://pwskills.com">PW Skills</a> to buy a course.
#     <br>
#     Take me to <a href="https://developer.mozilla.org/">MDN docs</a> to know more about Web Development.
#     <br>
#     Take me to <a href="https://pwskillslab.com">PW Skills Lab</a> to practice live coding.
# </body>
# </html>

# %% [markdown]
# **Q3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself**

# %% [markdown]
# **Ans.**
#
# ```
#
#
# <!--home.html-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>My Personal Blog- Home page</title>
# </head>
# <body>
#         <!-- naviagation contain hyperlink -->
#         <div>
#             <a href="home.html">Home Page</a> &nbsp;
#             <a href="webdev.html">Web Development</a> &nbsp;
#             <a href="webdesign.html">Web Design</a>&nbsp;
#         </div>
#
#         <!--  page content -->
#           <h1 style="color: rgba(4, 112, 235, 0.789);"> <u>Welcome to My Blog</u> </h1>
#         <p>
#             Hello! My name is Ankita. I am a Computer Science graduate ,passionate about <b>Web Development</b> and <b>Design</b>.
#             This blog is a small project where I share my learning, ideas, and knowledge about creating amazing websites.
#             Explore the other pages to learn about <i>Web Development</i> and <i>Web Design</i>.
#         </p>
# </body>
# </html>
#
#
#
# <!--webdev.html-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>My Blog-Web Development </title>
# </head>
# <body>
#         <!-- naviagation contain hyperlink -->
#         <div>
#             <a href="home.html">Home Page</a> &nbsp;
#             <a href="webdev.html">Web Development</a> &nbsp;
#             <a href="webdesign.html">Web Design</a>&nbsp;
#         </div>
#
#         <!--  page content -->
#           <h1 style="color: rgba(235, 4, 96, 0.789);"> <u>Web Development</u> </h1>
#         <p>
#             Web Development is the process of building and maintaining websites.
#             It involves <b>Frontend</b> (HTML, CSS, JavaScript) and <b>Backend</b> (PHP, Node.js, Python, databases) technologies.
#             Developers create websites that are fast, secure, and user-friendly to meet the needs of businesses and users worldwide.
#         </p>
# </body>
# </html>
#
#
# <!--webdesign.html-->
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>My Blog-Web Design </title>
# </head>
# <body>
#         <!-- naviagation contain hyperlink -->
#         <div>
#             <a href="home.html">Home Page</a> &nbsp;
#             <a href="webdev.html">Web Development</a> &nbsp;
#             <a href="webdesign.html">Web Design</a>&nbsp;
#         </div>
#
#         <!--  page content -->
#           <h1 style="color: rgba(185, 4, 235, 0.789);"> <u>Web Design</u> </h1>
#         <p>
#             Web Design focuses on the look, feel, and user experience of a website.
#             A good design uses principles of <i>typography, color, layout, and responsiveness</i> to make websites visually appealing and easy to use.
#             Designers often use tools like <b>Figma, Photoshop</b>, and modern CSS frameworks to craft beautiful interfaces.
#         </p>
# </body>
# </html>

# %% [markdown]
# **Q4.Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag.**

# %% [markdown]
# **Ans.**
#
# ```
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title> Assignment</title>
# </head>
# <body>
#     <h1> Tags and their description. </h1>
#     <ol>
#         <li><code>&lt;html&gt;</code> - Root element of an HTML document.</li><br>
#         <li><code>&lt;div&gt;</code> - Create division or section in blocl level HTML document.</li> <br>
#         <li><code>&lt;title&gt;</code> - Sets the title in the browser tab.</li><br>
#         <li><code>&lt;p&gt;</code> - Paragraph tag used to create paragraph.</li><br>
#         <li><code>&lt;img&gt;</code> - Image tag used to embed an image.</li><br>
#         <li><code>&lt;a&gt;</code> - Anchor tag used to add hyperlink.</li><br>
#         <li><code>&lt;br&gt;</code> - Line break.</li><br>
#         <li><code>&lt;ol&gt;</code> - Tag used to create Ordered list .</li><br>
#         <li><code>&lt;ul&gt;</code> - Tag used to create unordered list </li><br>
#         <li><code>&lt;li&gt;</code> - List item inside.</li><br>
#         <li><code>&lt;dl&gt;</code> - Description list.</li> <br>
#         <li><code>&lt;style&gt;</code> -Defines internal CSS styles .</li><br>
#         <li><code>&lt;h1&gt;-&lt;h6&gt;</code> – Headings from largest to smallest.</li><br>
#         <li><code>&lt;hr&gt;</code> - Horizontal rule (thematic break).</li><br>
#         <li><code>&lt;sub&gt;</code> - Subscript text.</li><br>
#         <li><code>&lt;sup&gt;</code> - Superscript text.</li><br>
#         <li><code>&lt;span&gt;</code> - Inline container for styling.</li><br>
#         <li><code>&lt;table&gt;</code> - Table container.</li><br>
#         <li><code>&lt;caption&gt;</code> - Table title.</li><br>
#         <li><code>&lt;tr&gt;</code> – Table row.</li><br>
#         <li><code>&lt;td&gt;</code> – Table data cell.</li><br>
#         <li><code>&lt;th&gt;</code> – Table header cell.</li><br>
#
#
#     </ol>
# </body>
# </html>

# %% [markdown]
# **Q5.Create a description list of full stack web development tech stack, using the < dl> tag. Each term should be
# a tech stack name and each description should be a brief explanation of what the tech stack is used for.**

# %% [markdown]
# **Ans.**
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Full Stack Web Development Tech Stack</title>
# </head>
# <body>
#     <h2>Full Stack Web Development Tech Stack</h2>
#     <dl>
#         <dt>HTML</dt>
#         <dd>Hypertext markup language used to structure content on web pages.</dd>
#
#         <dt>CSS</dt>
#         <dd>Stylesheet language used to control the layout, design, and presentation of web pages.</dd>
#
#         <dt>JavaScript</dt>
#         <dd>Programming language that makes web pages interactive and dynamic.</dd>
#
#         <dt>React.js</dt>
#         <dd>A popular front-end library for building user interfaces with reusable components.</dd>
#
#         <dt>Node.js</dt>
#         <dd>JavaScript runtime environment that allows building back-end services and APIs.</dd>
#
#         <dt>Express.js</dt>
#         <dd>A minimal and flexible Node.js framework for creating server-side applications.</dd>
#
#         <dt>MongoDB</dt>
#         <dd>NoSQL database used to store data in JSON-like documents, ideal for modern applications.</dd>
#
#         <dt>MySQL</dt>
#         <dd>Relational database management system widely used for structured data storage.</dd>
#
#         <dt>Git & GitHub</dt>
#         <dd>Version control system and online repository platform for managing source code.</dd>
#
#         <dt>REST API</dt>
#         <dd>Architectural style for designing networked applications using HTTP methods.</dd>
#
#         <dt>Docker</dt>
#         <dd>Platform for containerizing applications, making them portable and scalable.</dd>
#     </dl>
# </body>
# </html>

# %% [markdown]
# **Q6.Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits. Below is a reference image**
# ![Screenshot 2025-09-18 155617.png](data:image/png;base64,...)

# %% [markdown]
# **Ans.**
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Full Stack Web Development Tech Stack</title>
# </head>
# <body>
#     <h2>Full Stack Web Development Tech Stack</h2>
#     <ol>
#       <li>
#         <B>HTML</B><br><br>
#         <table border="2" cellspacing="1" cellpadding="2">
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/ Benefits</th>
#             </tr>
#             <tr>
#                 <td>Building the structure of web pages</td>
#                 <td>
#                     <ul>
#                         <li> Simple and easy to learn</li>
#                         <li> Compatible with all web browsers</li>
#                         <li> Allows for semantic markup</li>
#                     </ul>
#                 </td>
#             </tr>
#
#         </table>
#       </li>
#       <br>
#        <li>
#         <B>CSS</B><br><br>
#         <table border="2" cellspacing="1" cellpadding="2">
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/ Benefits</th>
#             </tr>
#             <tr>
#                 <td>Styling and layout of web pages</td>
#                 <td>
#                     <ul>
#                         <li> Allows for separation of content and presentation</li>
#                         <li> Enables responsive design</li>
#                         <li> Offer a wide range of styling option</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#       </li> <br>
#       <li>
#     <b>JavaScript</b><br><br>
#     <table border="2" cellspacing="1" cellpadding="2">
#         <tr>
#             <th>Primary Use Cases</th>
#             <th>Key Features/ Benefits</th>
#         </tr>
#         <tr>
#             <td>Making web pages interactive and dynamic</td>
#             <td>
#                 <ul>
#                     <li>Supports client-side and server-side programming</li>
#                     <li>Enables DOM manipulation</li>
#                     <li>Large ecosystem with frameworks and libraries</li>
#                 </ul>
#             </td>
#         </tr>
#     </table>
# </li><br>
#
#     </ol>
# </body>
# </html>

# %% [markdown]
# **Q7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# (< ul>) and list items  (< li>) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items**
#
# ![Screenshot 2025-09-18 155710.png](data:image/png;base64,...)

# %% [markdown]
# **Ans.**
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Table of Contents</title>
# </head>
# <body>
#     <h1><b>Table of Contents</b></h1>
#     <ul>
#         <li><u  style="color: rgb(45, 125, 252);"><b >Part 1: Introduction</b></u></li>
#          <li>
#             <u  style="color: rgb(45, 125, 252);"><b >Part 2: Getting Started</b></u>
#             <ul type="circle">
#                 <li><u  style="color: rgb(45, 125, 252);"><b >2.1 Installing the software</li> </b></u>
#                 <li><u  style="color: rgb(45, 125, 252);"><b >2.2 Creating a New Project</li> </b></u>
#                 <ul type="square">
#                     <li><u  style="color: rgb(45, 125, 252);"><b >2.2.1 Project Templates </li> </b></u>
#                     <li><u  style="color: rgb(45, 125, 252);"><b >2.2.2 Customizing Setting </li> </b></u>
#                 </ul>
#                 <li><u  style="color: rgb(45, 125, 252);"><b >2.3 Exploring the Interface</li> </b></u>
#                     <ul type="square">
#                         <li><u  style="color: rgb(45, 125, 252);"><b >2.3.1 Toolbar Featurs </li> </b></u>
#                         <li><u  style="color: rgb(45, 125, 252);"><b >2.3.2 Panel Layout </li> </b></u>
#                             <ul type="square">
#                                 <li><u  style="color: rgb(45, 125, 252);"><b >2.3.2.1 Docking Panels</li> </b></u>
#                                 <li><u  style="color: rgb(45, 125, 252);"><b >2.3.2.2 Tabbed Interface </li> </b></u>
#                             </ul>
#                      </ul>
#
#             </ul>
#         </li>
#         <li>
#             <u  style="color: rgb(45, 125, 252);"><b >Part 3: Advanced Topics</b></u>
#             <ul type="circle">
#                 <li><u  style="color: rgb(45, 125, 252);"><b >3.1 Working with Plugins </li> </b></u>
#                      <ul type="square">
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.1.1 Installing Plugins  </li> </b></u>
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.1.2 Plugins Configuration </li> </b></u>
#                     </ul>
#                 <li><u  style="color: rgb(45, 125, 252);"><b >3.2 Customizing the UI</li> </b></u>
#                     <ul type="square">
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.2.1 Changing Themes </li> </b></u>
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.2.2 Configuring Shortcuts</li> </b></u>
#                       </ul>
#                 <li><u  style="color: rgb(45, 125, 252);"><b >3.3 Optimizing Performance</li> </b></u>
#                     <ul type="square">
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.3.1 Caching Strategies </li> </b></u>
#                         <li><u  style="color: rgb(45, 125, 252);"><b >3.3.2 Resource  Minification </li> </b></u>
#                     </ul>
#
#             </ul>
#         </li>
#         <li><u  style="color: rgb(45, 125, 252);"><b >Part 4: Conclusion</b></u></li>
#
#     </ul>
# </body>
# </html>

# %% [markdown]
# **Q8. Create a table to display a conference schedule. Each row corresponds to a time slot, and each column
# corresponds to a room. Some time slots might have multiple sessions running simultaneously in different
# rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.
# (use table attribute “cellpadding”  to give extra padding in each table cell).**
#
#
# **Output should look like this**
#
# ![Screenshot 2025-09-18 155906.png](data:image/png;base64,...)

# %% [markdown]
# **Ans.**
# ```
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title>Conference Schedule</title>
# </head>
# <body>
#     <h1> Conference Schedule</h1>
#     <table border="2" cellpadding="7">
#         <tr>
#             <th>Time</th>
#             <th>Room 1</th>
#             <th>Room 2</th>
#             <th>Room 3</th>
#             <th>Room 4</th>
#         </tr>
#         <tr>       <!-- ROW 1-->
#             <td rowspan="3">9:00 AM - 10:00 AM</td>
#             <td rowspan="2">Keynote</td>
#             <td>Session A</td>
#             <td>Session B</td>
#             <td rowspan="3">Session C</td>
#         </tr>
#         <tr>  <!-- ROW 2-->
#             <td>Session D</td>
#             <td>Session E</td>
#         </tr>
#         <tr>   <!-- ROW 3-->
#             <td>10:00 AM - 11:30 AM</td>
#             <td colspan="2">Session F</td>
#         </tr>
#         <tr>   <!-- ROW 4-->
#             <td>12:00 PM - 1:00 PM</td>
#             <td colspan="4">Lunch Break</td>
#         </tr>
#         <tr>  <!-- ROW 5-->
#             <td rowspan="2">1:00 PM - 2:00 PM</td>
#             <td>Session G</td>
#             <td rowspan="2">Session H</td>
#             <td>Session I</td>
#             <td>Session L</td>
#         </tr><tr>  <!-- ROW 6-->
#             <td>Session K</td>
#             <td>Session J</td>
#             <td>Session M</td>
#         </tr>
#     </table>
# </body>
# </html>
