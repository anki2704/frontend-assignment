# %% [markdown]
# **Q1.  Describe the main differences between the CSS Flexbox layout model and the CSS Grid layout model. When
# would you choose to use one over the other?**

# %% [markdown]
# **Ans.**
#
# **Flexbox:**
#
#
# 1.Layout Dimension:Flexbox is one-dimensional and works in either a row or a column.
#
# 2.Content Flow vs Structured Layout:Flexbox is content-driven. The items flow based on the content size.
#
# 3.Positioning Control:
# Flexbox gives control along a single axis using properties like justify-content and align-items.
#
# 4.Use Cases:
# Flexbox is ideal for small components like navbars, buttons, or aligning items in a single row/column.
#
#
# 5.Choosing Between Them:Use Flexbox when the layout is in one direction.
#
#
#
#
#
#
# **CSS Grid:**
#
# 1.Layout Dimension:
# Grid is two-dimensional and handles both rows and columns at the same time
#
# 2.Content Flow vs Structured Layout:
# Grid is layout-driven. You define a structure first, and then place items into it.
#
# 3.Positioning Control:Grid allows precise placement using grid-template-rows, grid-template-columns, and grid-area.
#
# 4.Use Cases:Grid is better for page or section layouts like headers, sidebars, galleries, or dashboards.
#
# 5.Choosing Between Them:Use Grid when the layout needs both rows and columns.

# %% [markdown]
# **Q2.Explain the role of the following key properties in the Flexbox layout model**
#
#
# **1.justify-content**
#
# **2.align-item**
#
# **3.gap**
#
# **4.flex-direction**
#
# **5.flex-wrap**

# %% [markdown]
# **Ans.**
#
# 1.justify-content :- The justify-content property is used to align and distribute flex items along the main axis inside a flex container.
#
# 2.align-item:- The align-item property is used to align and distribute flex items along the cross axis inside a flex container.
#
# 3.gap:-  the gap property srts the space between the  felx items without using margins. It helps maintain equal spacing between elements.
#
# 4.flex-direction:- This property defines the direction of the main axis and determines how items are placed.
#
# Values:
#
# -row (default – left to right)
#
# -column (top to bottom)
#
# -row-reverse
#
# -column-reverse
#
# 5.Flex wrape:- the wrape property  controls whether items should stay in a single line or wrap to the next line when space is insufficient.

# %% [markdown]
# **Q3. Write the code to center a div using CSS Flexbox.**
#
#
# **Reference Image given below.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>asssigment</title>
#     <style>
#         body{
#             background-color: beige;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#         }
#         div{
#             width: 300px;
#             height: 300px;
#             border: 2px solid rgb(72, 235, 22);
#             background-color: rgb(72, 235, 22);
#         }
#     </style>
# </head>
# <body>
#     <div>
#
#     </div>
# </body>
# </html>

# %% [markdown]
# **Q4.A client of yours wants to add a pricing section on their website to showcase their newly introduced
# premium plans.**
#
# **You have to build the pricing section for their business. They have provided you with the figma design for the
# same. Link**
#
# ![Screenshot 2025-10-14 131921.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
# **html code: pricing_card.html**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Pricing Card</title>
#     <link rel="stylesheet" href="pricing-card.css">
#     <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@300;400;500;600;700&display=swap" rel="stylesheet">
#     <link rel="stylesheet" type="text/css" href="//fonts.googleapis.com/css?family=Nunito" />
# </head>
# <body>
#     <div class ="pricing-section">
#
#         <!-- card 1 -->
#         <div class="card1">
#             <div class="card-content">
#
#                 <div class="card-header">
#
#                     <div class="plan-header">
#
#                         <div class="plan-title-box"><h3 class="plan-title"> Free Plan</h3></div>
#                         <div class="description-box"><p class="description">For personal</p></div>
#                         <div class="price-box"><p class="price">$0 </p></div>
#                     </div>
#
#                     <div class="features">
#                         <ul class="feature-list">
#                             <li class="item1"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con1">  1 users </span></span> </li>
#                             <li class="item2"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con2">  4 Web mails </span></span></li>
#                             <li class="item3"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"> <span class="list-con3"> Responsive Website </span></span></li>
#                             <li class="item4"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con4">  Free SSL </span></span></li>
#                         </ul>
#                     </div>
#                 </div>
#                 <div class="suscribe-btn">
#                     <button class="btn1">Subscribe now</button>
#                 </div>
#            </div>
#         </div>
#
#
#         <!-- Card 2 -->
#            <div class="card2">
#             <div class="card-content">
#
#                 <div class="card-header">
#
#                     <div class="plan-header">
#
#                         <div class="plan-title-box"><h3 class="plan-title"> Basic Plan</h3></div>
#                         <div class="description-box"><p class="description2">For small business</p></div>
#                         <div class="price-box"><p class="price2">$29 </p></div>
#                     </div>
#
#                     <div class="features">
#                         <ul class="feature-list">
#                             <li class="item1"><span class="check"><img src="tick2.png" alt=""></span><span class="list-con-box"><span class="list-con1">  4 users </span></span> </li>
#                             <li class="item2"><span class="check"><img src="tick2.png" alt=""></span><span class="list-con-box"><span class="list-con2">  10 Web mails </span></span></li>
#                             <li class="item3"><span class="check"><img src="tick2.png" alt=""></span><span class="list-con-box"> <span class="list-con3"> Responsive Website </span></span></li>
#                             <li class="item4"><span class="check"><img src="tick2.png" alt=""></span><span class="list-con-box"><span class="list-con4">  Free SSL </span></span></li>
#                         </ul>
#                     </div>
#                 </div>
#                 <div class="suscribe-btn">
#                     <button class="btn2">Subscribe now</button>
#                 </div>
#            </div>
#         </div>
#
#
#
#          <!--  Card 3 -->
#              <div class="card3">
#             <div class="card-content">
#
#                 <div class="card-header">
#
#                     <div class="plan-header">
#
#                         <div class="plan-title-box"><h3 class="plan-title"> Pro Plan</h3></div>
#                         <div class="description-box"><p class="description3">For enterprise</p></div>
#                         <div class="price-box"><p class="price">$49 </p></div>
#                     </div>
#
#                     <div class="features">
#                         <ul class="feature-list">
#                             <li class="item1"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con1">  Unlimited users </span></span> </li>
#                             <li class="item2"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con2" > Unlimited Web mails  </span></span></li>
#                             <li class="item3"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"> <span class="list-con3"> Responsive Website </span></span></li>
#                             <li class="item4"><span class="check"><img src="tick.png" alt=""></span><span class="list-con-box"><span class="list-con4">  Free SSL+SEO </span></span></li>
#                         </ul>
#                     </div>
#                 </div>
#                 <div class="suscribe-btn">
#                     <button class="btn1">Subscribe now</button>
#                 </div>
#            </div>
#         </div>
#
#
#     </div>
# </body>
# </html>
#
#
#
#
#
#
#
# **css code: pricing-card.css**
#
# :root{
#     --primary-blue: #202842;
#     --card-bg: #F4F2FD;
#     --plan-white: #FFFFFF;
# ;
# }
# body{
#     width: 100vw;
#     height: 100vh;
#     display: flex;
#     justify-content: center;
#     align-items: center;
# }
# .pricing-section{
#     width:  962px;
#     height:  427px;
#     border: 1px solid #0b0b0b;
#     display: flex;
#     padding-top: 32px;
#     padding-right: 48px;
#     padding-bottom: 32px;
#     padding-left: 48px;
#     gap: 32px;
#     background-color: var(--card-bg);
#     flex-direction: row;
#
# }
# .card1{
#     width:  262px;
#     height:  363px;
#     box-shadow: 0px 1px 10px rgba(0, 0, 0, 0.25);
#     background-color:var(--plan-white);
#     color: var(--primary-blue);
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     padding: 32px;
#     gap: 32px;
#     border-radius:8px ;
# }
# .card-content{
#     width: 198px;
#     height: 306px;
#     gap: 32px;
# }
# .card-header{
#     width: 198px;
#     height: 236px;
#     gap: 16px;
#
# }
# .plan-header{
#     width: 198px;
#     height: 108px;
#     gap: 16px;
#
# }
# .plan-title-box{
#     padding-left: 8px;
#     padding-bottom: 4px;
#     padding-right: 8px;
#     padding-top: 4px;
#     width: 157px;
#     height: 40px;
#
# }
# .plan-title{
#     height: 32px;
#     font-family: Nunito;
#     font-weight: 700;
#     font-style: Bold;
#     font-size: 32px;
#     line-height: 32px;
#     letter-spacing: 0%;
#     margin: 0px;
#
# }
# .description-box{
#     width: 107px;
#     height: 16px;
#     padding-right: 8px;
#     padding-left: 8px;
#     gap: 10px;
#     opacity: 1;
#
# }
# .description{
#     width: 91px;
#     height: 16px;
#     font-family: Nunito;
#     font-size: 16px;
#     font-style: medium;
#     font-variant: normal;
#     font-weight: 500;
#     line-height: 16px;
#     letter-spacing: 0%;
#     color: var(--primary-blue);
#     margin: 0px;
#     margin-bottom: 8px;
# }
# .description2{
#     width: 161px;
#     height: 16px;
#     font-family: Nunito;
#     font-size: 16px;
#     font-style: medium;
#     font-variant: normal;
#     font-weight: 500;
#     line-height: 16px;
#     letter-spacing: 0%;
#     color: var(--plan-white);
#     margin: 0px;
#     margin-bottom: 8px;
# }
# .description3{
#     width: 161px;
#     height: 16px;
#     font-family: Nunito;
#     font-size: 16px;
#     font-style: medium;
#     font-variant: normal;
#     font-weight: 500;
#     line-height: 16px;
#     letter-spacing: 0%;
#     color: var(--primary-blue);
#     margin: 0px;
#     margin-bottom: 8px;
# }
# .list-con2{
#     width: auto;
#     height: 28px;
# }
# .price-box{
#     width: 58px;
#     height: 36px;
#     padding-right: 8px;
#     padding-left: 8px;
#     margin: 0px;
#     gap: 10px;
#     opacity: 1;
#
#
# }
# .price{
#     width: 42px;
#     height: 36px;
#     font-family: sans-serif;
#     font-size: 36px;
#     font-style:regular;
#     font-variant: normal;
#     font-weight: 400;
#     line-height: 36px;
#     letter-spacing: 0%;
#     margin: 0%;
#     margin-top: 10px;
#     color: var(--primary-blue);
#
#
# }
# .price2{
#     width: 42px;
#     height: 36px;
#     font-family: sans-serif;
#     font-size: 36px;
#     font-style:regular;
#     font-variant: normal;
#     font-weight: 400;
#     line-height: 36px;
#     letter-spacing: 0%;
#     margin: 0%;
#     margin-top: 10px;
#     color: var(--plan-white);
#
#
# }
#
# .features{
#     height: 112px;
#     width: 198px;
#     padding-left: 8px;
#
# }
# .feature-list{
#     list-style: none;
#     padding-left: 0px;
#     margin-top: 40px;
# }
# .item1{
#     width: 178px;
#     height:28px;
#     display: flex;
#
# }
# .item2{
#     width: 250px;
#     height:28px;
#     display: flex;
# }
# .item3{
#     width: 240px;
#     height:28px;
#     display: flex;
# }
# .item4{
#     width: 195px;
#     height:28px;
#     display: flex;
# }
# .list-con-box{
#     width: 65;
#     height: 28;
#     padding-top: 4px;
#     padding-right: 4px;
#     padding-bottom: 4px;
#     padding-left: 4px;
#     gap: 10px;
#     font-family: Nunito;
#     font-weight: 500;
#     font-style: Medium;
#     font-size: 16px;
#     line-height: 16px;
#     letter-spacing: 0%;
#
#
#
# }
#
# img{
#     width: 22px;
#     height: 22px;
# }
# .check{
#     width: 30px;
#     height: 28px;
#     padding-top: 3px;
#     padding-right: 4px;
#     padding-bottom: 3px;
#     padding-left: 4px;
#     gap: 10px;
#     opacity: 1;
#     left: 8px;
#
# }
# .suscribe-btn{
#     margin-top: 80px;
#     width: 156;
#     height: 38;
#     padding-top: 8px;
#     padding-right: 24px;
#     padding-bottom: 8px;
#     padding-left: 24px;
#     gap: 10px;
#     opacity: 1;
#     border-radius: 50px;
#
#
# }
# .btn1{
#     flex-flow: horizontal;
#     border-radius: 50px;
#     width:156px;
#     height: 38px;
#     padding-top: 8px;
#     padding-right: 24px;
#     padding-left: 24px;
#     padding-bottom:8px ;
#     gap: 8px;
#     background-color: var(--primary-blue);
#     color: var(--plan-white);
#     font-weight: 300;
#     size: 16px;
#     font-family: 'Nunito', sans-serif;
#     line-height: 22px;
#     font-style: semi-bold;
# }
# .btn2{
#     flex-flow: horizontal;
#     border-radius: 50px;
#     width:156px;
#     height: 38px;
#     padding-top: 8px;
#     padding-right: 24px;
#     padding-left: 24px;
#     padding-bottom:8px ;
#     gap: 8px;
#     background-color: var(--plan-white);
#     color: var(--primary-blue);
#     font-weight: 300;
#     size: 16px;
#     font-family: 'Nunito', sans-serif;
#     line-height: 22px;
#     font-style: semi-bold;
# }
# .card2{
#     width:  262px;
#     height:  363px;
#     box-shadow: 0px 1px 10px rgba(0, 0, 0, 0.25);
#     background-color:var(--primary-blue);
#     color: var(--plan-white);
#     display: flex;
#     flex-direction: column;
#     align-items: left;
#     padding: 32px;
#     gap: 32px;
#     border-radius:8px ;
# }
# .card3{
#     width:  262px;
#     height:  363px;
#     box-shadow: 0px 1px 10px rgba(0, 0, 0, 0.25);
#     background-color:var(--plan-white);
#     color: var(--primary-blue);
#     display: flex;
#     flex-direction: column;
#     align-items: left;
#     padding: 32px;
#     gap: 32px;
#     border-radius:8px ;
# }
#
#
#
#
# ![tick2.png](data:image/png;base64,...)![tick.png](data:image/png;base64,...)

# %% [markdown]
# **Q5.build a clone of the IRCTC Ticket booking page**
#
# **Assets can be downloaded from the figma file provided below**
#
#
# **Link to the figma file: Link**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
#
#
#
#
# **html code: IRCTC-Ticketbooking.html**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>IRCTC-Ticketbooking</title>
#     <link rel="stylesheet" href="IRCTC-Ticketbooking.css">
# </head>
# <body>
#
#     <div class="logo">
#         <img  src="logo2.png" alt="">
#         <img  src="logo1.png" alt="">
#     </div>
#      <div class="tain-pic" >
#         <img src="train.png" alt=""/>
#
#     </div>
#     <nav class="menu">
#         <ul class="menu-list">
#             <li>Ask Disha</li>
#             <li>Contact Us</li>
#             <li>Alerts</li>
#
#         </ul>
#          <div class="menu-btn">
#             <button style="background-color: #fb792b; color:#ffffff;" > Login </button>
#             <button > Register </button>
#             <button style="width: 400px;"> Agent Login</button>
#     </nav>
#     <div class="header-title">
#         <p class="header-line1"> Indian Railways</p>
#         <div class="header-line2">
#             <span class="header-line2" style="color:#01BB0A ;"> Safety</span>
#             <span class="header-line2" style="color: #fb792b;"> Security </span>
#             <span class="header-line2" style="color: #213d77;"> Punctuality</span>
#         </div>
#     </div>
#     <div class="Sub-Nutton">
#         <button class="sub-btn1"><img src="irctc1.png" alt="">BOOK Ticket </button>
#         <button class="sub-btn2"><img src="irctc2.png" alt="">PNR Status </button>
#         <button class="sub-btn3"><img src="irctc3.png" alt=""> Chart/ Vacancy</button>
#     </div>
#     <div class="search-train">
#         <div class="Rectangle-7">
#             <div class="from">
#                 <img src="irctc4.png" alt="">
#                 <div class="from-content">
#                     <p class="rect-top">From<span><img src="expand-img.png" alt=""></span></p>
#                     <p class="rect-mid"> Bangalore</p>
#                     <p class="rect-end" style="margin: 0px;">  KSR - Bangalore </p>
#                 </div>
#             </div>
#             <div class="swipe-logo">
#                 <img src="irctc9.png" alt="">
#             </div>
#             <div class="to">
#                 <img src="irctc5.png" alt="">
#                    <div class="to-content">
#                     <p class="rect-top">To<span><img src="expand-img.png" alt=""></span></p>
#                     <p class="rect-mid"> Kasaragod</p>
#                     <p class="rect-end" style="margin: 0px;">  KSR -  Kasaragod </p>
#                 </div>
#             </div>
#
#         </div>
#         <div class="Rectangle-8">
#             <div class="date"></div>
#             <img src="irctc6.png" alt="">
#             <div class="date-content">
#                 <ul>
#                     <li class="rect-top"> Date <img src="expand-img.png" alt=""></li>
#                     <li class="rect-mid"> 01 Aug 23 </li>
#                     <li class="rect-end"> Tuesday</li>
#
#                 </ul>
#             </div>
#              <div class="classs"></div>
#             <img src="irctc7.png" alt="">
#             <div class="class-content">
#                 <ul>
#                     <li class="rect-top"> Class <img src="expand-img.png" alt=""></li>
#                     <li class="rect-mid"> 3A </li>
#                     <li class="rect-end"> AC 3 Tier </li>
#
#                 </ul>
#             </div>
#
#              <div class="seat"></div>
#             <img src="irctc8.png" alt="">
#             <div class="seat-content">
#                 <ul >
#                     <li class="rect-top" > Seat Type <img src="expand-img.png" alt=""></li>
#                     <li class="rect-mid"> TATKAL </li>
#                     <li class="rect-end"> AC 3 Tier</li>
#                 </ul>
#             </div>
#
#
#         </div>
#
#     </div>
#     <div class="search-btnn">
#         <button class="search-btn"> Search Train <img src="arrow.png" alt=""></button>
#     </div>
#
#
# </body>
# </html>
#
#
#
#
#
#
# **css code:IRCTC-Ticketbooking.css**
# body{
#     background-color: #ffffff;
#     margin:0px 0px ;
# }
#
# img {
#   max-width: 100%;
#   height: auto;
#   display: block;
# }
#
# .tain-pic{
#     position: absolute;
#     top: 0;
#     right: 0;
#     width: auto;
#     height: auto;
#     max-height: 100vh;
#     max-width: 100vw;
#     object-fit: cover;
#     margin: 0px 0px;
#     margin-bottom: 0px;
#     display: flex;
# }
# .logo{
#     width: 189px;
#     height: 82px;
#     display: flex;
#     position: absolute;
#     top: 68px;
#     left: 102px;
#     gap: 30px;
# }
# .menu{
#     width: 350px;
#     height: 100px;
#     position: absolute;
#     top: 51px;
#     left: 800px;
#     gap: 20px;
# }
# .menu-list{
#     width: 300px;
#     height: 18px;
#     list-style: none;
#     display: flex;
#     flex-direction: row;
#     gap: 20px;
#    font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 550;
#     font-style: large;
#     font-size: 18px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     text-align: center;
#     padding:10px;
#     margin-bottom: 0px;
#
# }
# .menu-list li{
#
#    font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 500;
#     font-style: large;
#     font-size: 20px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     text-align: center;
#
#
# }
# .menu-btn{
#     width:auto;
#     height: 39px;
#     gap: 10px;
#     display: flex;
#
#
# }
# .menu-btn button{
#     width: 100%;
#     height: 39px;
#     padding: 10px 15px;
#     padding-left: 15px;
#     padding-right: 15px;
#     background-color: rgba(255, 255, 255, 1);
#     border-radius: 6px;
#     border: 1px solid rgba(51, 51, 51, 0.2);
#     font-family: "Roboto", "Helvetica", "Arial", sans-serif;
#     font-weight: 200;
#     font-style: small;
#     font-size: 15px;
#
#
#
# }
# .header-title{
#     width: 530px;
#     height: 120px;
#     position: absolute;
#     top: 180px;
#     left: 102px;
# }
# .header-line1{
#     width: auto;
#     height: 59px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 700;
#     font-style: Bold;
#     font-size: 65.67px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     margin:  30px 0px;
#
# }
# .header-line2{
#     width: auto;
#     height: 59px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 500;
#     font-style: Bold;
#     font-size: 37.67px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     display: inline-flex;
#     gap:50px ;
#
# }
# .Sub-Nutton{
#     display: flex;
#     width: 750px;
#     height: 56px;
#     position: absolute;
#     top: 410px;
#     left: 102px;
#     gap: 25px;
#     justify-content: space-between;
#
# }
# .sub-btn1{
#     width: 198px;
#     height: 44px;
#     display: flex;
#     align-items: center;
#     gap:11px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 600;
#     font-style: Bold;
#     font-size: 17px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     border-radius: 5px;
#     border: solid 1px #333333 50%;
#     padding: 10px 15px;
#     color: #ffffff;
#     background-color:#213d77;
#
#
# }
# .sub-btn2{
#     width: 188px;
#     height: 44px;
#     display: flex;
#     align-items: center;
#     gap:11px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 600;
#     font-style: Bold;
#     font-size: 17px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     border-radius: 5px;
#     border: solid 1px #333333 50%;
#     padding: 10px 15px;
# }
# .sub-btn3{
#     width: 228px;
#     height: 44px;
#     display: flex;
#     align-items: center;
#     gap:11px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 600;
#     font-style: Bold;
#     font-size: 17px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     border-radius: 5px;
#     border: solid 1px #333333 50%;
#     padding: 10px 15px;
# }
# .Sub-Nutton img{
#     width: 25;
#     height: 25;
#     float: left;
#     display: flex;
#     align-items: center;
# }
# .Rectangle-7{
#     width: 750px;
#     height: 130px;
#     top: 500px;
#     left: 101.39px;
#     opacity: 1;
#     border: solid 1px rgba( 51,5,51,0.1) ;
#     border-radius:11px ;
#     display: flex;
#     align-items: center;
#     position: absolute;
#     justify-content: space-around;
#
# }
# .from img{
#     float: left;
#     display: flex;
#     align-items: center;
#
#
#
#
# }
# .from-content{
#     font-family: Arial, Helvetica, sans-serif;
#     float: right;
#     padding: 0px;
#     margin: 0px;
#
#
# }
# .rect-end{
#     padding: 0px;
#     margin: 0px;
#
# }
# .rect-mid{
#
#     margin: 0px;
#     font-size: larger;
#     font-size: x-large;
#     font-weight: 700;
#     padding: 10px;
#     padding-left: 0px;
# }
# .rect-top{
#     padding-bottom: 0px;
#     margin: 0px;
# }
# .to-content{
#     font-family: Arial, Helvetica, sans-serif;
#     float: right;
#
# }
#
# .to img{
#     float: left;
#
# }
# .Rectangle-8{
#     font-size:large;
#     width: 750px;
#     height: 130px;
#     top: 670px;
#     left: 101.39px;
#     opacity: 1;
#     border: solid 1px rgba( 51,5,51,0.1) ;
#     border-radius:11px ;
#     display: flex;
#     align-items: center;
#     position: absolute;
#     justify-content: space-around;
#
# }
#
#
# .date-content{
#     font-family: Arial, Helvetica, sans-serif;
#     float: right;
#     padding: 0px;
#     margin: 0px;
# }
# .class-content{
#     font-family: Arial, Helvetica, sans-serif;
#     float: right;
#     padding: 0px;
#     margin: 0px;
# }
# .seat-content{
#     font-family: Arial, Helvetica, sans-serif;
#     float: right;
#     padding: 0px;
#     margin: 0px;
# }
#
#
# .Rectangle-8 ul {
#   list-style: none;
#   padding: 0;
#   margin: 0;
# }
#
# .rect-top {
#   display: flex;
#   align-items: center;
#   gap: 2px;
#   color: #555;
# }
#
# .rect-top img {
#   width: 14px;
#   height: 14px;
# }
#
# .rect-mid {
#   font-weight: bold;
#   font-size: 20px;
#   margin-top: 4px;
# }
#
# .rect-end {
#   font-size: 14px;
#   color: #777;
#   margin-top: 3px;
# }
# .search-btnn{
#     display: flex;
#     width: 750px;
#     height: 85px;
#     position: absolute;
#     top: 850px;
#     left: 102px;
#     gap: 25px;
#     justify-content: space-between;
#
# }
# .search-btn{
#     width: 750px;
#     height: 85px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     gap:11px;
#     font-family:Arial, Helvetica, sans-serif;
#     font-weight: 600;
#     font-style: Bold;
#     font-size: 27px;
#     line-height: 100%;
#     letter-spacing: 0%;
#     border-radius: 10px;
#     border: solid 1px #333333 50%;
#     padding: 10px 15px;
#     color: #ffffff;
#     background-color:  rgba(1, 187, 10, 1);
#
# }
