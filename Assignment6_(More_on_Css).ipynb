# %% [markdown]
#  **Q1.Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
# navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
# items must change their text color on hover**
#
# ![Screenshot 2025-10-04 203518.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>q1- Navigation bar</title>
#     <style>
#       .navbar{
#         background-color: rgb(2, 2, 255);
#         padding: 15px 0 15px 1px;
#
#       }
#       .nav-list {
#           list-style: none;
#           display:flex;
#           justify-content: center;
#           gap: 40px;
#           margin: 0;
#           padding: 0;
#       }
#       .nav-list li{
#         display: inline-block;
#
#       }
#       .nav-list a{
#         color: white;
#         text-decoration: underline;
#         font-size: large;
#         padding: 10px 15px;
#         transition: color 0.3s ease;
#
#       }
#       .nav-list a:hover {
#     color: #ff9800; /* Change text color on hover */
#     opacity: 0.9;
# }
#     </style>
# </head>
# <body>
#    <nav class="navbar">
#     <ul class="nav-list">
#             <li><a href="home.html">Home</a></li>
#             <li><a href="about us.html">About Us</a></li>
#             <li><a href="Contact.html">Contact</a></li>
#             <li><a href="Blog.html">Blog</a></li>
#             <li><a href="Login.html">Login</a></li>
#     </ul>
#    </nav>
#
#
# </body>
# </html>

# %% [markdown]
# **Q2.Create a div centered with an image and paragraph similar to the image mentioned below**
#
# ![Screenshot 2025-10-04 203723.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Card</title>
#     <style>
#         :root{
#             --card-bg:#ffc74e;
#         }
#         body{
#             justify-content: center;
#             height: 400px;
#             background-color: #f5f5f5;
#             align-items: center;
#             display: flex;
#             margin: 0px;
#
#         }
#         .card{
#             background-color:var(--card-bg) ;
#             width: 350px;
#             padding: 20px;
#             border-radius: 20px;
#             box-shadow: 0 4px 8px rgba(0,0,0,0.3);
#             text-align: center;
#         }
#         .card img{
#             padding:0;
#             width: 100%;
#             border-radius: 15px;
#         }
#         .card p{
#             margin: 10px;
#             text-align: left;
#             padding: 0px;
#
#
#         }
#         .card b{
#             font-weight: bold;
#
#
#         }
#
#     </style>
# </head>
# <body>
#     <div class="card">
#             <img src="img.png" alt=" course img">
#
#
#
#         <p>
#             <b>Course Name:</b> PW Skills full stack web development
#         </p>
#     </div>
# </body>
# </html>

# %% [markdown]
# **Q3. Create a navigation bar similar to question 1. For each navigation item, use a different border style.**

# %% [markdown]
# ```
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>q1- Navigation bar</title>
#     <style>
#       .navbar{
#         background-color: rgb(2, 2, 255);
#         padding: 15px;
#
#       }
#       .nav-list {
#           list-style: none;
#           display:flex;
#           justify-content: center;
#           gap: 40px;
#           margin: 0;
#           padding: 0;
#       }
#       .nav-list li{
#         display: inline-block;
#
#
#       }
#       .nav-list a{
#         color: white;
#         text-decoration: underline;
#         font-size: 15px;
#         padding: 10px 15px;
#         transition: color 0.1s ease;
#
#       }
#       .nav-list a:hover {
#         color: #ff9800; /* Change text color on hover */
#         opacity: 0.9;
#       }
#     .b1 a{
#       border: dotted #ff00e1 2px;
#
#     }
#     .b2 a{
#       border:dashed #00ffa6 2px;
#
#     }
#     .b3 a{
#       border: solid #03aafd 2px;
#
#     }
#     .b4 a{
#       border: groove #9a1414 4px;
#
#     }
#     .b5 a{
#       border: double #0c0c0c 4px;
#
#     }
#     </style>
# </head>
# <body>
#    <nav class="navbar">
#     <ul class="nav-list">
#             <li class="b1"><a href="home.html">Home</a></li>
#             <li class="b2"><a href="about us.html">About Us</a></li>
#             <li class="b3"><a href="Contact.html">Contact</a></li>
#             <li class="b4"><a href="Blog.html">Blog</a></li>
#             <li class="b5"><a href="Login.html">Login</a></li>
#     </ul>
#    </nav>
#
#
# </body>
# </html>

# %% [markdown]
# **Q4. Create a simple webpage with an image and make the image circular using border-radius**

# %% [markdown]
# ```
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title> Q4- Circular image</title>
#     <style>
#         .image{
#             height: 400px;
#             width: 400px;
#             border-radius: 50%;
#             border: 9px groove #1294df;
#             justify-content: center;
#             object-fit: cover;
#         }
#         .image-circle{
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background-color: #f0f0f0;
#             margin: 0px;
#
#         }
#         body{
#             margin: 0px;
#         }
#
#     </style>
# </head>
# <body>
#     <div class="image-circle">
#         <img src="https://i.pinimg.com/736x/15/8f/7d/158f7d22a38dccef8dfe7eb189f863eb.jpg" alt="profile picture" class="image">
#     </div>
# </body>
# </html>

# %% [markdown]
# **Q5.Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
# align center to the page, below the heading have an image of Google fonts and a paragraph about Google
# fonts in font “Montserrat” paragraph font style should be“montserrat” font.**

# %% [markdown]
# ```
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Q5 - Blog Google</title>
#     <link href="https://fonts.googleapis.com/css2?family=Oswald:wght@400;600&family=Montserrat:wght@400;500&display=swap" rel="stylesheet">
#
#     <style>
#         body{
#             margin: 0px;
#             font-family: 'Montserrat', sans-serif;
#             text-align: center;
#             display: block;
#             justify-content: center;
#             align-items: center;
#             background-color: rgb(250, 250, 250);
#
#         }
#         h1{
#             display: flex;
#             text-align: center;
#             justify-content: center;
#             font-weight: 500px;
#             font-size: xx-large;
#         }
#         img{
#             display: block;
#             width: 300px;
#             height: 150px;
#             margin: auto;
#             padding: auto;
#
#         }
#         p{
#            text-align: center;
#            font-size: medium;
#            font-family: 'montserrat', sans-serif;
#         }
#     </style>
# </head>
# <body>
#     <div>
#       <h1>Oswald</h1>
#     </div>
#     <div>
#         <img src="google.webp" alt="google logo">
#     </div>
#     <div>
#         <P>
#             Google Fonts is a free and open-source library that provides a wide variety of fonts for web and print design.
#             Developers and designers use Google Fonts to make their websites more visually appealing and readable without worrying about licensing issues.
#             The fonts can be easily embedded in a webpage using a simple link, allowing for consistent typography across all devices.
#             With hundreds of font families like Montserrat, Oswald, Roboto, and Lato, Google Fonts has become an essential tool for modern web design.
#         </P>
#     </div>
# </body>
# </html

# %% [markdown]
# **Q6.Create a simple website as mentioned in the below image. You can get the assets by visiting https://
# pwskills.com/about-us.**
# ![Screenshot 2025-10-04 204053.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>pwskills/about-us</title>
#     <style>
#         body{
#             margin: 20px;
#             background-color: white;
#             padding-left: 10%;
#             padding-right: 10%;
#             overflow: hidden;
#
#         }
#         h1{
#             font-family: Arial, sans-serif;
#             justify-content: center;
#             padding: 50px;
#             block-size: 10px;
#             text-align: center;
#         }
#         p{
#             font-family:  ui-sans-serif, system-ui, sans-serif;
#             font-size: small;
#             line-height: 1.6;
#             color: #333;
#             text-align: left;
#             margin-bottom: 20px;}
#         img{
#             display: block;
#             margin: 0px;
#             width: 100%;
#             height: min-content;
#             padding: 0px;
#             border-radius: 5px;
#             object-fit: cover;
#         }
#
#         div img{
#             margin-bottom: 20px;
#
#         }
#     </style>
# </head>
# <body>
#     <div>
#         <h1>About Us</h1>
#     </div>
#     <div>
#         <p> PW Skills' mission is to permeate through every student/professional's
#             outlook towards jobs and change their attitude and perspective from
#             "How Can I Do It?" to "Of Course I Can Do It". We aim to do this by
#             providing exceptional up skilling courses at affordable rates, while
#             being tech-forward so anyone,anywhere can access and improve their
#             ability to be successful in life.
#         </p>
#     </div>
#     <div >
#         <img src="aboutUs.png" alt="about us image" >
#     </div>
# </body>
# </html>

# %% [markdown]
# **Q7.Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
# default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.**
#
# ![Screenshot 2025-10-04 204228.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Q6. Hover PW card</title>
#
#
#     <style>
#              body{
#                 display: flex;
#                 align-items: center;
#              }
#
#              div{
#                 border: solid #84f1cd 1px;
#              }
#                 .card{
#                     justify-content: center;
#                     align-items: center;
#                     text-align: center;
#                     width: 350px;
#                     height: 250px;
#                     padding: 10px;
#                     margin: 20px;
#                     background-color:#84f1cd;
#                     border-radius: 25px;
#                 }
#                 div img{
#                     height: 200px;
#                     width: 100%;
#                     margin-top: 0px;
#
#                 }
#                 div p{
#                     font-size: medium;
#                     font-weight: 600px;
#                     color: rgb(0, 0, 0);
#                     margin-top: 0px;
#                     padding-top: 15px;
#                 }
#                 div:hover{
#
#                    opacity: 50%;
#                 }
#
#     </style>
# </head>
# <body>
#
#
#     <div class="card">
#         <img src="card.png" alt=" course img">
#
#         <p>
#             <b>Course Name:</b> PW Skills full stack web development
#         </p>
#      </div>
#
# </body>
# </html>

# %% [markdown]
# **Q8. Create a simple list of items as mentioned in the below image.**![Screenshot 2025-10-04 204335.png](data:image/png;base64,...)

# %% [markdown]
# ```
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Q7- simple list</title>
#     <style>
#         body{
#             border: solid #000000 2px;
#             display: block;
#             width: 500px;
#             padding: 10px;
#             padding-top: 0px;
#
#         }
#     </style>
# </head>
# <body>
#       <h1> Requirements</h1>
#       <ol type="i">
#         <li>System with minimum i3 processor or better.</li>
#         <li>At least 4 GB of RAM.</li>
#         <li>Working internet connection.</li>
#         <li>Dedication to learn.</li>
#       </ol>
# </body>
# </html
